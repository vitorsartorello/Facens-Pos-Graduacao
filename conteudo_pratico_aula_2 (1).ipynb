# %% [markdown]
# ### Exercício 1: Função Simples - Soma de Dois Números
#
# **Objetivo:** Criar uma função que some dois números.
#
# **Descrição:** Escreva uma função chamada `somar` que receba dois números como argumentos e retorne a soma deles.

# %%
# Digite seu código aqui
def somar(x,y):
  soma=x+y
  return soma

soma=somar(4,8)
print(f'A soma dos números é: {soma}')
# Out:
# A soma dos números é: 12

# %% [markdown]
# ### Exercício 2: Função com Condicional - Verificar Par ou Ímpar
#
# **Objetivo:** Criar uma função que verifique se um número é par ou ímpar.
#
# **Descrição:** Escreva uma função chamada `verificar_par_impar` que receba um número inteiro como argumento e retorne a string "Par" se o número for par, e "Ímpar" se for ímpar.
#
# **Exemplo de uso:**

# %%
# Digite seu código aqui
def verificar_par_impar(x):
  if x%2==0:
    print('par')
  else:
    print('impar')

verificar_par_impar(87)
# Out:
# impar

# %% [markdown]
# ### Exercício 3: Leitura de Arquivo - Exibir Conteúdo
#
# **Objetivo:** Ler um arquivo de texto e exibir seu conteúdo na tela.
#
# **Descrição:** Crie um arquivo de texto simples (por exemplo, `conteudo.txt`). Escreva um código que leia este arquivo linha por linha e imprima cada linha no console.
#
# **Conteúdo de exemplo para `conteudo.txt`:**

# %%
# Digite seu código aqui
with open('conteudo.txt','w',encoding='utf-8') as f:
  f.write('vamos ver quantas linhas vai dar \nisso é para ser uma outra\nagora mais uma\nota e\nota')
  f.write('vamos ver quantas linhas vai dar \nisso é para ser uma outra\nagora mais uma\nota e\nota')
  f.write('vamos ver quantas linhas vai dar \nisso é para ser uma outra\nagora mais uma\nota e\nota')


leitura_linha=open('conteudo.txt','r',encoding='utf-8')
conteudo=leitura_linha.read()
print(conteudo.strip())
leitura_linha.close()
# Out:
# vamos ver quantas linhas vai dar
# isso é para ser uma outra
# agora mais uma
# ota e
# otavamos ver quantas linhas vai dar
# isso é para ser uma outra
# agora mais uma
# ota e
# otavamos ver quantas linhas vai dar
# isso é para ser uma outra
# agora mais uma
# ota e
# ota

# %% [markdown]
# ### Exercício 4: Escrita em Arquivo - Diário Simples
#
# **Objetivo:** Permitir que o usuário escreva entradas em um arquivo de diário.
#
# **Descrição:** Escreva um código que peça ao usuário para digitar uma entrada de diário. A entrada deve ser salva em um arquivo chamado `diario.txt`, adicionando a nova entrada ao final do arquivo a cada vez que o código for executado. Adicione uma quebra de linha após cada entrada.
#
# **Formato do arquivo `diario.txt` após algumas entradas:**

# %%
# Digite seu código aqui
# Passo 1: pedir a entrada do usuário
entrada = input("Digite sua entrada do diário: ")

# Passo 2: abrir o arquivo para adicionar no final
with open("diario.txt", "a", encoding="utf-8") as f:
    # Passo 3: escrever a entrada no arquivo
    # Lembre de adicionar '\n' no final para cada nova linha
    f.write(entrada + "\n")

# Passo 4 (opcional): ler e mostrar todas as entradas
with open("diario.txt", "r", encoding="utf-8") as f:
    for linha in f:
        print(linha.strip())
# Out:
# Digite sua entrada do diário: sdakmkldasmdskaçl
# oi oioi
# dsmaikmdask
# asmdklasdmkladsmklads
# sdakmkldasmdskaçl

# %% [markdown]
# ### Exercício 5: Combinando Funções e Arquivos - Contador de Linhas de Arquivo
#
# **Objetivo:** Criar uma função que conte o número de linhas em um arquivo.
#
# **Descrição:** Escreva uma função chamada `contar_linhas` que receba o nome de um arquivo como argumento e retorne o número total de linhas neste arquivo. Use esta função para contar as linhas de um arquivo de exemplo.
#
# **Arquivo de exemplo para contar:**

# %%
# Digite seu código aqui

def contar_linhas(arquivo):
  linhas=0
  with open(arquivo,'r',encoding='utf-8' ) as f:
   for linha in f:
    linhas+=1
   return linhas
   print (linhas)

print(f'{contar_linhas('diario.txt')} linhas')
# Out:
# 4 linhas

# %% [markdown]
# Criar um arquivo TXT contendo atividades e status das atividades, uma linha por atividade e logo abaixo da linha o status da atividade.
#
# Deve ter um menu e implementar as opções de incluir atividade, remover atividade e concluir atividade e todas as operações devem ser gravadas no arquivo

# %%
# Função para escolher o status
def escolha_status():
    escolha = ''
    while escolha not in ['1','2','3']:
        escolha = input('Digite o número do status: ')
        if escolha == '1':
            status = 'Não iniciada'
        elif escolha == '2':
            status = 'Em andamento'
        elif escolha == '3':
            status = 'Concluída'
        else:
            print('Número inválido!')
    return status

# Função para adicionar atividades
def add_atividades():
    # Pede o nome da atividade
    atividade = input('Digite o nome da atividade: ')

    # Menu de status
    print("Escolha o status da atividade:")
    print("1 - Não iniciada")
    print("2 - Em andamento")
    print("3 - Concluída")

    # Escolha do status
    status = escolha_status()

    # Grava no arquivo em modo append
    with open('atividades.txt','a',encoding='utf-8') as f:
        f.write(f"{atividade}\n")
        f.write(f"{status}\n")

    print(f"Atividade '{atividade}' com status '{status}' adicionada com sucesso!\n")
    return atividade, status

# Função para mudar status
def mudar_status():
  # Listar as atividades em números
  with open('atividades.txt','r',encoding='utf-8') as f:
    linhas = f.readlines()
    atividades = []
    for i in range(0, len(linhas), 2):
      atividade = linhas[i].strip()
      status = linhas[i+1].strip()
      atividades.append((atividade, status))
    for id, (atividade, status) in enumerate(atividades, 1):
      print(f"{id}. {atividade} - {status}")

  while True:
    escolha = input("Digite o número da atividade que deseja atualizar: ")

    if escolha.isdigit():
        escolha = int(escolha)
        if 1 <= escolha <= len(atividades):  # len(atividades) é o total de atividades
            index = escolha - 1  # converte para índice da lista (começa em 0)
            break
        else:
            print("Número fora do intervalo, tente novamente.")
    else:
        print("Entrada inválida, digite um número.")

  novo_status = escolha_status()
  atividades[index][1] = novo_status
  with open('atividades.txt', 'w', encoding='utf-8') as f:
        for atividade, status in atividades:
            f.write(f"{atividade}\n")
            f.write(f"{status}\n")
  print(f"Status da atividade '{atividades[index][0]}' atualizado para '{novo_status}'!\n")

# Função para listar atividades
def listar_atividades():
    with open('atividades.txt','r',encoding='utf-8') as f:
        linhas = f.readlines()

    atividades = []
    for i in range(0, len(linhas), 2):
        atividade = linhas[i].strip()
        status = linhas[i+1].strip()
        atividades.append((atividade, status))

    print("Atividades:")
    for id, (atividade, status) in enumerate(atividades, 1):
        print(f"{id}. {atividade} - {status}")

# %%
# Função para escolher o status
def escolha_status():
  # Menu de status
    print("Escolha o status da atividade:")
    print("1 - Não iniciada")
    print("2 - Em andamento")
    print("3 - Concluída")
    escolha = ''
    while escolha not in ['1','2','3']:
        escolha = input('Digite o número do status: ')
        if escolha == '1':
            status = 'Não iniciada'
        elif escolha == '2':
            status = 'Em andamento'
        elif escolha == '3':
            status = 'Concluída'
        else:
            print('Número inválido!')
    return status

# Função para adicionar atividades
def add_atividades():
    # Pede o nome da atividade
    atividade = input('Digite o nome da atividade: ')

    # Escolha do status
    status = escolha_status()

    # Grava no arquivo em modo append
    with open('atividades.txt','a',encoding='utf-8') as f:
        f.write(f"{atividade}\n")
        f.write(f"{status}\n")

    print(f"Atividade '{atividade}' com status '{status}' adicionada com sucesso!\n")
    return atividade, status

# Função para mudar status
def mudar_status():
  # Listar as atividades em números
  with open('atividades.txt','r',encoding='utf-8') as f:
    linhas = f.readlines()
  atividades = []
  for i in range(0, len(linhas), 2):
      atividade = linhas[i].strip()
      status = linhas[i+1].strip()
      atividades.append([atividade, status])
  for id, (atividade, status) in enumerate(atividades, 1):
      print(f"{id}. {atividade} - {status}")

  while True:
    escolha = input("Digite o número da atividade que deseja atualizar: ")

    if escolha.isdigit():
        escolha = int(escolha)
        if 1 <= escolha <= len(atividades):  # len(atividades) é o total de atividades
            index = escolha - 1  # converte para índice da lista (começa em 0)
            break
        else:
            print("Número fora do intervalo, tente novamente.")
    else:
        print("Entrada inválida, digite um número.")

  novo_status = escolha_status()
  atividades[index][1] = novo_status
  with open('atividades.txt', 'w', encoding='utf-8') as f:
        for atividade, status in atividades:
            f.write(f"{atividade}\n")
            f.write(f"{status}\n")
  print(f"Status da atividade '{atividades[index][0]}' atualizado para '{novo_status}'!\n")

# Função para remover atividades
  def remover_atividade():
    # Ler todas as atividades do arquivo
    with open('atividades.txt','r', encoding='utf-8') as f:
        linhas = f.readlines()

    atividades = []
    for i in range(0, len(linhas), 2):
        atividades.append([linhas[i].strip(), linhas[i+1].strip()])

    # Mostrar atividades numeradas
    print("Atividades:")
    for idx, (atividade, status) in enumerate(atividades, 1):
        print(f"{idx}. {atividade} - {status}")

    # Escolher qual atividade remover
    while True:
        escolha = input("Digite o número da atividade que deseja remover: ")
        if escolha.isdigit():
            escolha = int(escolha)
            if 1 <= escolha <= len(atividades):
                index = escolha - 1
                break
            else:
                print("Número fora do intervalo, tente novamente.")
        else:
            print("Entrada inválida, digite um número.")

    # Remover atividade selecionada
    atividade_removida = atividades.pop(index)

    # Regravar o arquivo com as atividades restantes
    with open('atividades.txt','w', encoding='utf-8') as f:
        for atividade, status in atividades:
            f.write(f"{atividade}\n")
            f.write(f"{status}\n")

    # Confirmar remoção
    print(f"Atividade '{atividade_removida[0]}' removida com sucesso!\n")

# Função para listar atividades
def listar_atividades():
    with open('atividades.txt','r',encoding='utf-8') as f:
        linhas = f.readlines()

    atividades = []
    for i in range(0, len(linhas), 2):
        atividade = linhas[i].strip()
        status = linhas[i+1].strip()
        atividades.append([atividade, status])

    print("Atividades:")
    for id, (atividade, status) in enumerate(atividades, 1):
        print(f"{id}. {atividade} - {status}")

# MENU PRINCIPAL BASEADO NAS FUNÇÕES
while True:
  print('----Menu----')
  print('1 - Adicionar atividades')
  print('2 - Listar atividades')
  print('3 - Mudar status de uma atividade')
  print('4 - Remover uma atividade')
  print('0 - Sair')

  escolha=input('Escolha uma opção: ')

  if escolha=='1':
    add_atividades()
  elif escolha=='2':
    listar_atividades()
  elif escolha=='3':
    mudar_status()
  elif escolha=='4':
    remover_atividade()
  elif escolha=='0':
    print('Até a próxima!!')
    break
  else:
    print('Opção inválida! Digite um número da lista.')
# Out:
# ----Menu----
# 1 - Adicionar atividades
# 2 - Listar atividades
# 3 - Mudar status de uma atividade
# 0 - Sair
# Escolha uma opção: 3
# 1. PASSEAR - Não iniciada
# Digite o número da atividade que deseja atualizar: 1
# Escolha o status da atividade:
# 1 - Não iniciada
# 2 - Em andamento
# 3 - Concluída
# Digite o número do status: 2
# Status da atividade 'PASSEAR' atualizado para 'Em andamento'!
#
# ----Menu----
# 1 - Adicionar atividades
# 2 - Listar atividades
# 3 - Mudar status de uma atividade
# 0 - Sair
# Escolha uma opção: 2
# Atividades:
# 1. PASSEAR - Em andamento
# ----Menu----
# 1 - Adicionar atividades
# 2 - Listar atividades
# 3 - Mudar status de uma atividade
# 0 - Sair
# Escolha uma opção: 1
# Digite o nome da atividade: ALMOÇAR
# Escolha o status da atividade:
# 1 - Não iniciada
# 2 - Em andamento
# 3 - Concluída
# Digite o número do status: 3
# Atividade 'ALMOÇAR' com status 'Concluída' adicionada com sucesso!
#
# ----Menu----
# 1 - Adicionar atividades
# ...
